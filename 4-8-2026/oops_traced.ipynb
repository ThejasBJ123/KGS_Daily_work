# %% [markdown]
# # Python Study Notebook: Oops
# ### Questions, Unchanged User Code, Detailed Logic & Step-by-Step Code Tracing
#
# ---

# %% [markdown]
# ## Section 1: class fan:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class fan:): Implement and trace the Python program for class fan:.**
#
# ---
# ### 💻 My Code

# %%
class fan:
    def __init__(self):
        self.brand="usha"
        self.colour="black"
        self.cost=1899
        self.blades=5

    def rotate(self):
        print("Fan is rotating")

f1=fan()
print(f1)

f2 = f1
print(f2)

print(id(f1))
print(id(f2))
# Out:
# <__main__.fan object at 0x0000019042767D00>
# <__main__.fan object at 0x0000019042767D00>
# 1719101979904
# 1719101979904

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, rotate` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 2: class Demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class Demo:
    def __init__(self):
        self.x=10
        self.y=20

    def display(self):
        print(self.x)
        print(self.y)
        self.z=35
        print(self.z)


m1=Demo()
print(m1.x)
print(m1.y)

m1.display()
print(m1.z)

print("\n")
m1.display() # method we can't print(m1.display())
# Out:
# 10
# 20
# 10
# 20
# 35
# 35
#
#
# 10
# 20
# 35

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, display` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 3: class Demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class Demo:
    def __init__(self):
        self.x=10
        self.y=20

    def display(self):
        print(self.x)
        print(self.y)
        self.z=35
        print(self.z)


m1=Demo()
print(m1.x)
print(m1.y)

m1.display()
print(m1.z)

m1.a=30
print(m1.a)
# Out:
# 10
# 20
# 10
# 20
# 35
# 35
# 30

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, display` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 4: class demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class demo:
    x=10
    def __init__(self):
        self.y=20

    def display(self):
        print(self.y)
        print(demo.x)

d1=demo()
print(demo.x)
print(d1.y)

demo.x=200
print(demo.x)

c=d1.y+demo.x
print(c)
# Out:
# 10
# 20
# 200
# 220

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, display` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 5: class Manage:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Manage:): Implement and trace the Python program for class manage:.**
#
# ---
# ### 💻 My Code

# %%
class Manage:
    def __init__(self ):
        self.vistor_id=""
        self.vistor_name=""
        self.Company="" 
        self.mobile=""
        self.person_to_meet=""
        self.departement=""
        self.purpose=""
        self.entry_time=" " 
        self.exit_time=""
    
    def checkIn(self):
        print("========Vistor Check-In ========")
        vistor_id=input("enter  vister id : ")
        visitor_name=input("Enter vistor name : ")
        Company=input("Enter the company name : ")
        mobile=int(input("Enter the Moblie number : "))
        person_to_meet=input("Person to meet :")
        departement=input("Departement: ")
        purpose=input("Purpose of visit: ")
        entry_time=int(input("entry the time(hours 0-23): "))
        print("vistor checked in successfully")


    def checkOut(self):
        print("================= vistor check-out ==============")
        exit_time=int(input("exit time(hour 0-23): "))

    def guidelines(self):
        print("===vistor guidelines======")
        print("1. wear your vistor ID card")
        print("2. photography is not allowed")
        print("3. Follow the company security rules")
        print("4. return visitor pass befor leaving")
        print("5. smoking is prohited")
        pritn("6. report the reception while exiting")

    def exit(self):
        print("Exit from the vistor mangament system")



print("======= \n KAIZENTRIX GLOBAL SOLUTIONS \n  Corparate vistor management system \n ====================== ")
obj= Manage()
while obj:
    print("1. Vistor  check-In \n 2. vistor check-Out \n 3. vistor guidelines \n 4. exit ")

    ch=int(input("Enter the choice: "))



    if ch==1:
        obj.checkIn()

    elif ch==2:
        obj.checkOut()

    elif ch==3:
        obj.guidelines()

    else:
        obj.exit()
# Out:
# =======
#  KAIZENTRIX GLOBAL SOLUTIONS
#   Corparate vistor management system
#  ======================
# 1. Vistor  check-In
#  2. vistor check-Out
#  3. vistor guidelines
#  4. exit
# ================= vistor check-out ==============
# 1. Vistor  check-In
#  2. vistor check-Out
#  3. vistor guidelines
#  4. exit
# ================= vistor check-out ==============
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 57
#      54     obj.checkIn()
#      56 elif ch==2:
# ---> 57     obj.checkOut()
#      59 elif ch==3:
#      60     obj.guidelines()
#
# Cell In[12], line 28, in Manage.checkOut(self)
#      26 def checkOut(self):
#      27     print("================= vistor check-out ==============")
# ---> 28     exit_time=int(input("exit time(hour 0-23): "))
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, checkIn, checkOut, guidelines, exit` to encapsulate reusable task logic.
# 2. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.
# 3. **Conditional Branching (`if-else`):** Evaluates boolean expressions to branch execution path.
# 4. **For Loop Iteration:** Iterates through sequence/range bounds (`range(start, stop)`).
# 5. **While Loop Control:** Continues execution while state control condition evaluates to `True`.
# 6. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).
# 7. **Return Statement:** Passes calculated result back to caller function.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 6: class Manage:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Manage:): Implement and trace the Python program for class manage:.**
#
# ---
# ### 💻 My Code

# %%
class Manage:
    def __init__(self ):
        self.vistor_id=""
        self.vistor_name=""
        self.Company="" 
        self.mobile=""
        self.person_to_meet=""
        self.departement=""
        self.purpose=""
        self.entry_time=" " 
        self.exit_time=""
    
    def checkIn(self):
        print("========Vistor Check-In ========")
        vistor_id=input("enter  vister id : ")
        visitor_name=input("Enter vistor name : ")
        Company=input("Enter the company name : ")
        mobile=int(input("Enter the Moblie number : "))
        person_to_meet=input("Person to meet :")
        departement=input("Departement: ")
        purpose=input("Purpose of visit: ")
        entry_time=int(input("entry the time(hours 0-23): "))
        print("vistor checked in successfully")


    def checkOut(self):
        print("================= vistor check-out ==============")
        exit_time=int(input("exit time(hour 0-23): "))

    def guidelines(self):
        print("===vistor guidelines======")
        print("1. wear your vistor ID card")
        print("2. photography is not allowed")
        print("3. Follow the company security rules")
        print("4. return visitor pass befor leaving")
        print("5. smoking is prohited")
        pritn("6. report the reception while exiting")

    def exit(self):
        print("Exit from the vistor mangament system")



print("======= \n KAIZENTRIX GLOBAL SOLUTIONS \n  Corparate vistor management system \n ====================== ")
obj= Manage()
while obj:
    print("1. Vistor  check-In \n 2. vistor check-Out \n 3. vistor guidelines \n 4. exit ")

    ch=int(input("Enter the choice: "))



    if ch==1:
        obj.checkIn()

    elif ch==2:
        obj.checkOut()

    elif ch==3:
        obj.guidelines()

    else:
        obj.exit()

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, checkIn, checkOut, guidelines, exit` to encapsulate reusable task logic.
# 2. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.
# 3. **Conditional Branching (`if-else`):** Evaluates boolean expressions to branch execution path.
# 4. **For Loop Iteration:** Iterates through sequence/range bounds (`range(start, stop)`).
# 5. **While Loop Control:** Continues execution while state control condition evaluates to `True`.
# 6. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).
# 7. **Return Statement:** Passes calculated result back to caller function.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---
