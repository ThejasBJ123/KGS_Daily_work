# %% [markdown]
# # Recursion - Number Operations
#
# Recursive programs for digit counting, factorial calculation, sum of natural numbers, and sum of digits.

# %% [markdown]
# ### Question 1
# Write a Python program for: **count digits**

# %%
 # count digits 

def isCount(n,count):

    if n<=0:
        return count

    n=n//10
    count+=1
    return isCount(n, count)


num=int(input("enter the number : "))
c = isCount(num,0)
print("Number of digits:",num,"is: ", c)
# Out:
# Number of digits: 15 is:  2

# %% [markdown]
# ### Question 2
# Write a Python program for: **count digits**

# %%
 # count digits 

def isCount(n,count):

    if n<=0:
        return count
    return isCount(n//10, count + 1)


num=int(input("enter the number : "))
c = isCount(num,0)
print("Number of digits:",num,"is: ", c)
# Out:
# Number of digits: 4563 is:  4

# %% [markdown]
# ### Question 3
# Write a Python program for: **count digits**

# %%
 # count digits 

def isCount(n,count):

    if n<=0:
        return count
    return isCount(n//10, count + 1)

def isAsn(n, pow, asn, temp):
    if n<=0:
        return temp==asn

    base=n%10
    asn=asn+(base**pow)
    n=n//10
    return isAsn( n, pow, asn, temp)
        

num=int(input("enter the number : "))

pow = isCount(num,0)

if isAsn(num, pow, 0, num):
    print(num, " is an ASN")
else:
    print(num,"is not ASN")
# Out:
# 153  is an ASN

# %% [markdown]
# ### Question 4
# Write a Python program for: **factorial**

# %%
# factorial

def factorial(n):
    if n <= 1:
        return 1

    return n * factorial(n - 1)


num = int(input("Enter the number: "))
res = factorial(num)

print("The factorial of", num, "is:", res)
# Out:
# The factorial of 4 is: 24

# %% [markdown]
# ### Question 5
# Write a Python program for: **Python Program Implementation 5**

# %%
def displayfactors(n, i):
    if i > n:
        return

    if n % i == 0:
        print(i, end=" ")

    return displayfactors(n, i + 1)


num = int(input("Enter the num: "))
displayfactors(num, 1)
# Out:
# 1 5

# %% [markdown]
# -	WAP to display the sum of the first “n” natural numbers.
# 	N = 5  5+4+3+2+1 =15

# %%
def sum_num(n, sum):

    if n <= 0:
        return sum

    sum = sum + n
    print(n)
    n = n - 1


    return sum_num(n, sum)

num = int(input("Enter the number: "))

result = sum_num(num, 0)

print("Sum is:", result)
# Out:
# 3
# 2
# 1
# Sum is: 6

# %% [markdown]
# -	WAP to sum all the digits present in a given number.
# 	N = 5481
# 	N = 5481 	0+1
# 	N = 548 	1+8
# 	N = 54  	9+4
# 	N = 5 		13+5
# 	N = 0		ret 18

# %%
def sum_num(n, sum):

    if n <= 0:
        return sum

    digit = n % 10
    sum = sum + digit

    n = n // 10

    return sum_num(n, sum)


num = int(input("Enter the number: "))

result = sum_num(num, 0)

print("Sum is:", result)
# Out:
# Sum is: 13

# %% [markdown]
# ## Theory & Key Concepts Used in the Codes
#
# 1. **Recursive Digit Count**: `countDigits(n // 10) + 1`.
# 2. **Recursive Factorial**: `n * factorial(n - 1)`.
# 3. **Recursive Sum**: Accumulating sum of digits and natural numbers recursively.
