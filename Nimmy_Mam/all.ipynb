# %% [markdown]
# ### even or odd number

# %%
def evenOdd(n):
    return n%2==0

num=int(input("Enter the number : "))
if evenOdd(num):
    print(num, " even number ")
else: 
    print(num, " odd number ")

# %% [markdown]
# ### Leap Year

# %%
def leapyear(year):
    return (year%100!=0 and year%4==0) or (year%400==0)

num=int(input("enter the Year : "))
if leapyear(num):
    print(num, " leap year ")
else:
    print(num, " not a leap year ")

# %% [markdown]
# ### CountDigit

# %%
def countDigit(n):
    count=0
    while n>0:
        n=n//10
        count+=1
    return count

n=int(input("enter the number : "))
res=countDigit(n)
print(" the count digit",n,"is: ",res)

# %%
# using recursion 
def countD(n, count):
    if n<=0:
        return count

    return countD(n//10, count+1)


n=int(input("enter the number : "))
c=countD(n,0)
print(c)

# %% [markdown]
# ### ASN

# %%
# wap to display all the asn's present in a user defined range separalety

def CountDigit(n):
    count=0
    while n>0:
        n=n//10
        count+=1
    return count

def isASN(n):
    temp=n
    if n<0:
        n=n*-1
    asn, pow=0, CountDigit(n)

    while n>0:
        base =n%10
        asn=asn+(base**pow)
        n=n//10

    if temp<0:
        asn=asn*-1

    return temp==asn

sn=int(input("enter the start number "))
en=int(input("enter the end number "))

if sn>en:
    print("invalid number")
else:
    print("asn numnber :" )
    for i in range(sn, en+1): # increment loop
        if isASN(i):
            print(i, end=" ")


    print("\n")

    print("not a asn : ")
    for i in range (sn, en+1): 
        if not isASN(i):
            print(i,end=" ")
# Out:
# asn numnber :
# 153
#
# not a asn :
# 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143 144 145 146 147 148 149 150 151 152 154 155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233 234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269 270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287 288 289 290 291 292 293 294 295 296 297 298 299 300

# %%
# WAP to display all the ASN's present in a user-defined range separately   decrment loop

def CountDigit(n):
    count = 0

    while n > 0:
        n = n // 10
        count += 1

    return count


def isASN(n):
    temp = n

    if n < 0:
        n = n * -1

    asn, pow = 0, CountDigit(n)

    while n > 0:
        base = n % 10
        asn = asn + (base ** pow)
        n = n // 10

    if temp < 0:
        asn = asn * -1

    return temp == asn


sn = int(input("Enter the start number: "))
en = int(input("Enter the end number: "))

if sn > en:
    print("Invalid number")
else:
    print("ASN numbers:")

    # Decrement loop
    for i in range(en, sn - 1, -1): # decrment loop
        if isASN(i):
            print(i, end=" ")

    print("\n")

    print("Not an ASN:")

    for i in range(en, sn - 1, -1):
        if not isASN(i):
            print(i, end=" ")

# %%
# using recursion

def countdigit(n, count):
    if n<=0:
        return count
    return countdigit(n//10, count+1)

def isAsn(n,temp , asn, pow):
    if n<=0:
        return temp==asn 
    
    base=n%10
    asn=asn+(base**pow)
    n=n//10

    return isAsn(n, temp, asn , pow)

n=int(input("enter the number : "))

pow=countdigit(num, 0)

if isAsn(num, num, 0, pow):
    print(num, "ASN")
else:
    print(num,"not ASN")

# %% [markdown]
# ### revers the number

# %%
def reverse(n):
    temp=n
    if n<0:
        n=n*-1

    rev=0
    while n>0:
        base=n%10
        rev=(rev*10)+base
        n=n//10

    if temp<0:
        rev=rev*-1

    return rev

n=int(input(" enter the number: "))
res=reverse(n)
print( " THE REVERS NUMBER ", n,"is : ",res)
# Out:
#  THE REVERS NUMBER  5369 is :  9635

# %%
# recursion 

def reverse(n, rev):
    if n<=0:
        return rev
    
    base=n%10
    rev=(rev*10)+base
    n=n//10
    return reverse(n, rev)

n=int(input("Eneter the number : "))
res=reverse(n,0)
print( " THE REVERS NUMBER ", n,"is : ",res)

# %% [markdown]
# ### palindrome

# %%
def palindrome(n):
    temp=n
    if n<0:
        n=n*-1

    rev=0
    while n>0:
        base=n%10
        rev=(rev*10)+base
        n=n//10
        
    if temp<0:
        rev=rev*-1

    return rev==temp

num=int(input("enter the num: "))
if palindrome(num):
    print(" palindrome ", num)
else:
    print("not Palindrome", num)
# Out:
#  palindrome  121

# %%
# recursion 

def pal(n,rev,temp):

    if n<=0:
        return rev == temp
    
    base=n%10
    rev=(rev*10)+base
    n=n//10
    return pal(n, rev, temp)

num=int(input("enter the num: "))
if pal(num, 0, num):
    print(" palindrome ", num)
else:
    print("not Palindrome", num)
# Out:
#  palindrome  232

# %% [markdown]
# ### factors , count factor, count cycle using logic 1

# %%
def factors(n):
    for i in range(1,n+1):
        if n%i==0:
            print(i, end=" ")
    

def countFactor(n):
    countfact=0
    for i in range(1, n+1):
        if n%i==0:
            countfact+=1
    return countfact
 
def countCycle(n):
    countcycle=0
    for i in range(1,n+1):
        countcycle+=1
    return countcycle


def isprime(n):
    count=0
    for i in range(1, n+1): 
        if n%i==0:
            count+=1
    return count ==2

num = int(input("Enter the num: "))
print("The factors of", num, "are:")
factors(num)

res=countFactor(num)
print("countdigit: ", res)

rec=countCycle(num)
print("countcycle: ",rec)

if isprime(num):
    print("Prime number : ",num)

else:
    print("not prime number : ", num)

# %%
def factor(n, i):
    if i>n:
        return 

    if n%i==0:
        print(i,end=" ")

    factor(n,i+1)

def countdigit(n,i, countfact):
    if i>n:
        return countfact

    if n%i==0:
        countfact+=1
    return countdigit(n, i+1 , countfact)

def isPrime(n,i,count):
    if i>n:
        return count==2

    if n%i==0:
        count+=1
    return isPrime(n, i+1, count)

    
    
num=int(input("Enter the number : "))
print(" factors: ")
factor(num,1)

res=countdigit(num,1,0 )
print("count digit: ",res)

if isPrime(num, 1, 0):
    print("Prime number : ",num)

else:
    print("not prime number : ", num)

# %% [markdown]
# ### factors using square root logic 2

# %%
def factor(n):
    i=1
    while  i*i<=n:
        if n%i==0:
            print(i,end=" ")
            if i!=(n//i):
                print((n//i),end=" ")
        i+=1

def countFactor(n):
    i=1
    count=0
    while i*i<=n:
        if n%i==0:
            count +=1
            if i!=n//i:
                count+=1
        i+=1
    return count

def prime(n):
    i=1
    count=0
    while i*i<=n:
        if n%i==0:
            count+=1
            if i!=n//i:    
                count+=1
        i+=1
    return count==2


num=int(input("enter the number : "))
print("factor  : ")
factor(num)

res=countFactor(num)
print("\n count digit: ", res)

if prime(num):
    print(" prime number : ", num)
else: 
    print("not primenumber : ", num)

# %%
 # recursion using square root logic

def count(n, i):
    if i*i>n:
        return

    if n%i==0:
        print(i,end=" ")

        if i!=n//i:
            print(n//i, end =" ")

    count(n,i+1)


def countfacts(n, i, count):
    if i*i>n:
        return count

    if n%i==0:
        count+1

        if i !=n//i:
             count+=1

    return countfacts(n, i+1, count)


def isPrime(n, i, count):
    if i*i>n:
        return count==2

    if n%i==0:
        count+=1

        if i!=n//i:
            count+=1
    return isPrime(n,i+1,count)
    

num = int(input("Enter the number: "))

print("Factors:")
count(num, 1)

res =countfacts(num, 1,0)
print("\nNumber of factors:", res)



p = isPrime(num, 1, 0)

if p:
    print("Prime number")
else:
    print("Not a prime number")

# %% [markdown]
# ### GCD/hcf

# %%
def gcd(n1,n2):
    lower=n1
    if n1>n2:
        lower=n2

    hcf=1
    for i in range(2,(lower+1)):
        if n1%i==0 and n2%i==0:
            hcf=i
    return hcf

f_num =int(input("enter the first number : "))
s_num=int(input("Enter the second number : "))
  

res= gcd(f_num, s_num)
print( " the hcf of ",f_num,"and ",s_num," is: ", res)

# %%
# recursion of gcd

def gcd(n1,n2,i, hcf, lower):
    if i>lower:
        return hcf
    if n1%i==0 and  n2%i==0:
        hcf=i

    return gcd(n1,n2,i+1,hcf,lower)
f_num =int(input("enter the first number : "))
s_num=int(input("Enter the second number : "))

lower=f_num
if f_num>s_num:
    lower=s_num
  
res= gcd(f_num, s_num, 1,1,lower)
print( " the hcf of ",f_num,"and ",s_num," is: ", res)
# Out:
#  the hcf of  5 and  25  is:  5

# %% [markdown]
# ### coprime

# %%
def coprime(n1, n2):
    lower=n1
    if n1>n2:
        lower=n2

    hcf=1
    for i in range(2, (lower+1)):
        if n1%i==0 and n2%i==0:
            hcf=i
    return hcf ==1


num1=int(input("enter the first number: "))
num2=int(input("Enter the secont number : "))


if coprime(num1, num2):
     print(" co prime number " , num1, num2)
    
else: 
    print("not a coprime number ")

# %%
# recursion 
def coprime(n1, n2, i, hcf, lower):
    if i>lower:
        return hcf==1

    if n1%i==0 and n2%i==0:
        hcf=i

    return coprime(n1, n2, i+1, hcf, lower)

num1 = int(input("Enter the number: "))
num2 = int(input("Enter the number: "))

lower = num1

if num2 < num1:
    lower = num2

result = coprime(num1, num2, 1, 1, lower)

if result :
    print("Coprime")
else:
    print("Not Coprime")

# %% [markdown]
# ### euclidian's algogrithm

# %%
# GCD 
def gcd(n1,n2):
    if n1==0:
        return n2

    if n1<n2:
        n1, n2=n2, n1

    return gcd(n1%n2, n2)

n1=int(input())
n2=int(input())
x=gcd(n1,n2)
print(x)
# Out:
# 4

# %%
# Coprime
def gcd(n1,n2):
    if n1==0:
        return n2==1

    if n1<n2:
        n1,n2=n2,n1
    
    return gcd(n1%n2, n2)

num1 = int(input("Enter the number: "))
num2 = int(input("Enter the number: "))

result = gcd(num1, num2)

if result:
    print("Coprime")
else:
    print("Not Coprime")

# %% [markdown]
# ### LCM

# %%
def lcm(n1, n2):
    lcm=n1
    if n1<n2:
        lcm=n2
    while  True:
        if lcm%n1==0 and lcm%n2==0:
            return lcm
        lcm+=1

f_num=int(input("Enter the first number : "))
s_num=int(input("Enter the second number : "))


res=lcm(f_num, s_num)
print("LCM 1 : ",res)

# %%
# recursion 

def Lcm(n1,n2,lcm):
    if (n1*n2==lcm):
        return lcm


    if lcm%n1==0 and lcm%n2==0:
        return lcm 
    return Lcm(n1, n2, (lcm+1))

n1=int(input("Enter the first number : "))
n2=int(input("Enter the second number : "))

lcm=n1
if n2>n2:
    lcm=n2 

res=Lcm(n1,n2, lcm)
print("The LCM : ", res)

# %% [markdown]
# ### Fibonacii

# %%
# Fibonacci - decrement number

def Fibonacci1(pos):
    n1, n2 = 0, 1

    while pos > 0:
        print(n1, end=" ")

        temp = n1 + n2
        n1 = n2
        n2 = temp

        pos -= 1


# Fibonacci - decrement number using for loop

def Fibonacci3(pos):
    n1, n2 = 0, 1

    for i in range(pos, 0, -1):
        print(n1, end=" ")

        temp = n1 + n2
        n1 = n2
        n2 = temp


# Fibonacci - increment number using for loop

def Fibonacci4(pos):
    n1, n2 = 0, 1

    for i in range(1, pos + 1):
        print(n1, end=" ")

        temp = n1 + n2
        n1 = n2
        n2 = temp


pos = int(input("Enter the number: "))

print("Fibonacci using while loop:")
Fibonacci1(pos)

print("\n========================")

print("Fibonacci using decrement for loop:")
Fibonacci3(pos)

print("\n========================")

print("Fibonacci using increment for loop:")
Fibonacci4(pos)
# Out:
# Fibonacci using while loop:
# 0 1 1 2 3
# ...
# Fibonacci using decrement for loop:
# 0 1 1 2 3
# ...
# Fibonacci using increment for loop:
# 0 1 1 2 3

# %%
# Fibonacci - decrement number using recursion

def Fibonacci3(pos, n1=0, n2=1):
    if pos > 0:
        print(n1, end=" ")

        temp = n1 + n2
        n1 = n2
        n2 = temp

        return Fibonacci3(pos - 1, n1, n2)


pos = int(input("Enter the number: "))

Fibonacci3(pos)
# Out:
# 0 1 1 2 3

# %%
# Fibonacci - increment number using recursion

def Fibonacci4(pos, i=1, n1=0, n2=1):
    if i <= pos:
        print(n1, end=" ")
        temp = n1 + n2
        n1 = n2
        n2 = temp

        return Fibonacci4(pos, i + 1, n1, n2)


pos = int(input("Enter the number: "))

Fibonacci4(pos)
# Out:
# 0 1 1 2 3

# %%
# show nth fibonocci
def nthFibo(pos):
    if pos<=1: 
        return pos

    return nthFibo(pos-1) + nthFibo(pos-2)


pos=int(input("Enter the num: "))

res =nthFibo(pos)
print("The val present at pos: ", pos, "is: ", res )
# Out:
# The val present at pos:  9 is:  34

# %% [markdown]
# ### happy number

# %%
def happyNum(n):

    if n == 1:
        return True
    elif n == 4:
        return False

    sum = 0

    while n > 0:
        base = n % 10
        sum = sum + (base * base)
        n = n // 10

    return happyNum(sum)


n = int(input("Enter a num: "))

if happyNum(n):
    print(n, "is a happy num")
else:
    print(n, "is not a happy num")

# %% [markdown]
# ### factorial

# %%
def factorial(n):
    fact = 1
    for i in range(2, n + 1): # 1 is not required 1 * any thing is any thing 
        fact *= i
    return fact



num=int(input("enrter the number: "))

res = factorial(num)
print(" the factorial number is : " ,res)
# Out:
#  the factorial number is :  120

# %%
# recursion function 

def Factorial(n):
    if n<=1:
        return 1
    return  n*Factorial(n-1)


num=int(input("enter the num:"))
res=Factorial(num)

print("the fact of  ",num,"is:", res)
# Out:
# the fact of   5 is: 120
