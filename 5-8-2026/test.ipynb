# %% [markdown]
# Reverse a number
# 1.  write a code to revese to  a number using customize function
# 2. wap to reverse a number present in a user defined range
# 3. wap to display the first n natural nume in reve order
# eg: n=15
# 1 2 3 4 5 6 7 7 9 1 11 21 31 41 51

# %% [markdown]
# integer palindrome
# 1. cheak weather the number is palindrome or not
# 2. cheakc weather the palindrome in the user range
# 3. cheack weather the first n palindrome

# %%
class Solution:
	def reverseDigits(self, n):
		# Code here
		temp=n
		if n<0:
		    n=n*-1
		rev=0
		
		while n>0:
		    rem=n%10
		    rev=(rev*10)+rem
		    n=n//10
		    
	    if temp<0:
	        rev=rev*-1
	       
	    return rev
	   

num=int(input("enter the number : "))

f1=solution()

print(f1.reverseDigits())
# Out:
#   File <tokenize>:14
#     if temp<0:
#     ^
# IndentationError: unindent does not match any outer indentation level
