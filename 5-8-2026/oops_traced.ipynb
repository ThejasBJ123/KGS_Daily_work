# %% [markdown]
# # Python Study Notebook: Oops
# ### Questions, Unchanged User Code, Detailed Logic & Step-by-Step Code Tracing
#
# ---

# %% [markdown]
# ## Section 1: class Inters:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Inters:): Implement and trace the Python program for class inters:.**
#
# ---
# ### 💻 My Code

# %%
class Inters:
    def __init__(self, intern_name, intern_id, intern_age, intern_mob):
        self.name=intern_name
        self.Iid=intern_id
        self.age=intern_age
        self.mob=intern_mob

    def Intern_details(self):
        print(self.name)
        print(self.Iid)
        print(self.age)
        print(self.mob)


i1=Inters("raju",12,25,9959)
i1.Intern_details()
# Out:
# raju
# 12
# 25
# 9959

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, Intern_details` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 2: class Inters:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Inters:): Implement and trace the Python program for class inters:.**
#
# ---
# ### 💻 My Code

# %%
class Inters:
    def __init__(self, intern_name, intern_id, intern_age, intern_mob):
        self.name=intern_name
        self.Iid=intern_id
        self.age=intern_age
        self.mob=intern_mob

    def Intern_details(self):
        print(self.name)
        print(self.Iid)
        print(self.age)
        print(self.mob)

name=input("Enter the name: ")
Iid=input("enter the id: ")
age=int(input("Enter the age : "))
mob=int(input("enter the mobile : "))


i1=Inters(name,Iid,age,mob)
i1.Intern_details()
# Out:
# adfd
# asdf3
# 34
# 34433

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, Intern_details` to encapsulate reusable task logic.
# 2. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.
# 3. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 3: class Farmer:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Farmer:): Implement and trace the Python program for class farmer:.**
#
# ---
# ### 💻 My Code

# %%
class Farmer:
    r=2.5
    def __init__(self, p, t):
        self.p=p
        self.t=t
    
    def Simple_calculatore(self):
        si=(self.p*self.t*self.r)/100
        print(si)

s1=Farmer(1000,2)
s1.Simple_calculatore()
# Out:
# 50.0

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, Simple_calculatore` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 4: class demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class demo:
    a=10  # static var
    def __init__(self):
        self.b=20 # instance var
        self.c=30
    def display(self):  #instace method
        d=45   #local var
        print(d)

d1=demo()
print(demo.a)
print(d1.b)
print(d1.c)


d1.display()
z=50   #local var
print(z)
# Out:
# 10
# 20
# 30
# 45
# 50

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `__init__, display` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---
