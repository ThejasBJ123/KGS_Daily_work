# %% [markdown]
# # Python Study Notebook: Oop
# ### Questions, Unchanged User Code, Detailed Logic & Step-by-Step Code Tracing
#
# ---

# %% [markdown]
# ## Section 1: str="Kaizentrixglobal"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (str="Kaizentrixglobal"): Implement and trace the Python program for str="kaizentrixglobal".**
#
# ---
# ### 💻 My Code

# %%
str="Kaizentrixglobal"
print(len(str))
print(str[2])

print(str[-14])
print(str[3:7:1])
print(str[10:16])
print(str[10:])
print(str[:])
print(str[1:13])
print(str[1:6:2])
print(str[10:3:+1])
print(str[10:3:-1])
print(str[-14:-8:-1])
print(str[-8:-4:-1])
print(str[-8:-4:1])
print(str[::-1])
#print(str[-8: -4:0])
# Out:
# 16
# i
# i
# zent
# global
# global
# Kaizentrixglobal
# aizentrixglo
# azn
#
# gxirtne
#
#
# ixgl
# labolgxirtneziaK

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 2: str1= "Rama "
#
# ### ❓ Question / Problem Statement
# **Problem Statement (str1= "Rama "): Implement and trace the Python program for str1= "rama ".**
#
# ---
# ### 💻 My Code

# %%
str1= "Rama "
str2="sita "

print(str1)

str3=str1+" "+str2
print(str3)

# str4= str1-str2
# print(str4)

# str5=str1*str2
# print(str5)

str6=str1*2
print(str6)

# str7=str/str2
# print(str7)
# Out:
# Rama
# Rama  sita
# Rama Rama

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 3: str1="Arjuna"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (str1="Arjuna"): Implement and trace the Python program for str1="arjuna".**
#
# ---
# ### 💻 My Code

# %%
str1="Arjuna"
str2="Bhima"
str3="Nakula"

print(str1)
print(str2)
print(str3)

str4="Arjuna"
str5="Bhima"
str6="Nakula"

print(str4)
print(str5)
print(str6)

print(id(str1))
print(id(str4))

print(id(str2))
print(id(str5))

print(id(str3))
print(id(str6))
# Out:
# Arjuna
# Bhima
# Nakula
# Arjuna
# Bhima
# Nakula
# 2233438039792
# 2233438039792
# 2233438029552
# 2233438029552
# 2233438032560
# 2233438032560

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 4: str="Kaizentrixglobal"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (str="Kaizentrixglobal"): Implement and trace the Python program for str="kaizentrixglobal".**
#
# ---
# ### 💻 My Code

# %%
str="Kaizentrixglobal"
print(len(str))
print(str[2])

print(str[-14])
print(str[3:7:1])
print(str[10:16])
print(str[10:])
print(str[:])
print(str[1:13])
print(str[1:6:2])
print(str[10:3:+1])
print(str[10:3:-1])
print(str[-14:-8:-1])
print(str[-8:-4:-1])
print(str[-8:-4:1])
print(str[::-1])
#print(str[-8: -4:0])
# Out:
# 16
# i
# i
# zent
# global
# global
# Kaizentrixglobal
# aizentrixglo
# azn
#
# gxirtne
#
#
# ixgl
# labolgxirtneziaK

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 5: str1="arjuna"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (str1="arjuna"): Implement and trace the Python program for str1="arjuna".**
#
# ---
# ### 💻 My Code

# %%
str1="arjuna"

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---
