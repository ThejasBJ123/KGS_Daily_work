# %% [markdown]
# GCD /HCF
# -------
# --> Greates common divisor/highest common factor
# --> given two numbers find the common factors that divides both the I/p num's down to 0 and return the hightest factor amongst them
# --> the lower will never hava a factor in the higher range of the larger num
#
# * wap to find the GCD/ HCF  of the given 2 num's

# %%
# wap to check the number 
def Hcf_num(n1,n2):
    lower = n1
    if n2<n1:
        lower=n2

    hcf=1
    for i in range(2,(lower+1)):
        if n1%i==0 and n2%i==0:
            hcf=i

    return hcf
   

f_num =int(input("enter the first number : "))
s_num=int(input("Enter the second number : "))
  

res= Hcf_num(f_num, s_num)
print( " the hcf of ",f_num,"and ",s_num," is: ", res)
# Out:
#  the hcf of  6 and  2  is:  2

# %% [markdown]
# ### Question 2
# Write a Python program for: **Python Program Implementation 2**

# %%
def Hcf_num1(n1,n2):
    lcm=n1
    if n2>n1:
        lcm=n2

    while True:
        if lcm % n1 == 0 and lcm % n2 ==0:
            return lcm
        lcm += 1
def Hcf_num2(n1, n2):
    lcm=n1
    if n2>n1:
        lcm=n2

    while n1*n2!= lcm:
        if lcm % n1 == 0 and lcm % n2 ==0:
            return lcm
        lcm += 1

f_num=int(input("Enter the first number : "))
s_num=int(input("Enter the second number : "))


res=Hcf_num(f_num, s_num)
print("LCM 1 : ",res)


res=Hcf_num2(f_num, s_num)
print("LCM 2 : " ,res )
# Out:
# LCM 1 :  60
# LCM 2 :  60

# %% [markdown]
# Co- Prime's
# ----------
#
# * if the HCF/ GCD of the given 2 num's is exactly 1, then they are said to be the co-Prime's of the each other
#
# eg:
#    n1 =18     n2= 19    hcf=1 ==> co - prime's
#    n1=21      n2 = 18  hcf = 3 ===> not co primes's
#
# * wap to check weather the given 2 num's are coprime or each other or not

# %%
# wap to check weather the given 2 num's are coprime or each other or not 
def isCoprime(n1,n2):
    lower=n1
    if n2 < n1 :  
        lower=n2
    hcf =1
    for i in range(2, (lower+1)):
        if n1%i==0 and n2%i==0:
            hcf=i
    return hcf==1


num1=int(input("enter the first number: "))
num2=int(input("Enter the secont number : "))


if isCoprime(num1, num2):
     print(" co prime number ")
    
else: 
    print("not a coprime number ")

# %% [markdown]
# # wap to display the factoriol  of given num
# eg =
#    n=5  ---> 5*4*3*2*1 =120
#    n=1   -->1
#    n=0 ----> 1
#    n=3  ----> 3*2*1

# %%
def factorial(n):
    fact = 1
    for i in range(2, n + 1): # 1 is not required 1 * any thing is any thing 
        fact *= i
    return fact



num=int(input("enrter the number: "))

res = factorial(num)
print(" the factorial number is : " ,res)
# Out:
#  the factorial number is :  120

# %% [markdown]
# # wap to display the fibonacci series of a given number
# - given any position the inital 2 val's of the series will always be 0 and 1
#
# - the next position val is the sum of previous 2 positions.

# %%
# increment number 
def Fibonacci1(pos):
    n1,n2=0,1
    while pos>0:
        print(n1, end=" ")
        temp=n1+n2
        n1=n2
        n2=temp
        pos-=1


def Fibonacci3(pos):
    n1, n2=0,1
    for i in range(pos, 1,-1,-1):
        print(n1, end=" ")
        temp=n1 +n2
        n1=n2
        n2=temp


def Fibonacci4(pos):
    n1,n2= 0,1
    for i in range(1, pos+1):
        print(n1, end=" ")
        temp =n1+n2
        n1=n2
        n2=temp
    
pos=int(input("Enter the number: "))
Fibonacci(pos)


print("========================")
Fibonacci3(pos)

# %% [markdown]
# ### Question 6
# Write a Python program for: **Python Program Implementation 6**

# %%
def Fibonacci(pos):
    n1,n2=0,1
    count=0
    while count<=pos:
        print(n1, end=" ")
        temp=n1+n2
        n1=n2
        n2=temp

    count+=1
    
pos=int(input("Enter the number: "))
Fibonacci(pos)

# %% [markdown]
# ## Theory & Key Concepts Used in the Codes
#
# 1. **GCD / HCF**: Highest common factor dividing two numbers.
# 2. **Co-Prime Numbers**: Pair of numbers whose GCD is `1`.
# 3. **Factorial**: Product of all positive integers up to $n$ ($n! = n \times (n-1) \times \dots \times 1$).
# 4. **Fibonacci Series**: Sequence where next number is sum of previous two ($a, b = b, a+b$).
# 5. **Functions**: Creating specialized modular functions for math algorithms.
