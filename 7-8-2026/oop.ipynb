# %% [markdown]
# ### Question 1
# Write a Python program for: **Python Program Implementation 1**

# %%
str="Kaizentrixglobal"
print(len(str))
print(str[2])

print(str[-14])
print(str[3:7:1])
print(str[10:16])
print(str[10:])
print(str[:])
print(str[1:13])
print(str[1:6:2])
print(str[10:3:+1])
print(str[10:3:-1])
print(str[-14:-8:-1])
print(str[-8:-4:-1])
print(str[-8:-4:1])
print(str[::-1])
#print(str[-8: -4:0])
# Out:
# 16
# i
# i
# zent
# global
# global
# Kaizentrixglobal
# aizentrixglo
# azn
#
# gxirtne
#
#
# ixgl
# labolgxirtneziaK

# %% [markdown]
# ### Question 2
# Write a Python program for: **Python Program Implementation 2**

# %%
str1= "Rama "
str2="sita "

print(str1)

str3=str1+" "+str2
print(str3)

# str4= str1-str2
# print(str4)

# str5=str1*str2
# print(str5)

str6=str1*2
print(str6)

# str7=str/str2
# print(str7)
# Out:
# Rama
# Rama  sita
# Rama Rama

# %% [markdown]
# ### Question 3
# Write a Python program for: **Python Program Implementation 3**

# %%
str1="Arjuna"
str2="Bhima"
str3="Nakula"

print(str1)
print(str2)
print(str3)

str4="Arjuna"
str5="Bhima"
str6="Nakula"

print(str4)
print(str5)
print(str6)

print(id(str1))
print(id(str4))

print(id(str2))
print(id(str5))

print(id(str3))
print(id(str6))
# Out:
# Arjuna
# Bhima
# Nakula
# Arjuna
# Bhima
# Nakula
# 2233438039792
# 2233438039792
# 2233438029552
# 2233438029552
# 2233438032560
# 2233438032560

# %% [markdown]
# ### Question 4
# Write a Python program for: **Python Program Implementation 4**

# %%
str="Kaizentrixglobal"
print(len(str))
print(str[2])

print(str[-14])
print(str[3:7:1])
print(str[10:16])
print(str[10:])
print(str[:])
print(str[1:13])
print(str[1:6:2])
print(str[10:3:+1])
print(str[10:3:-1])
print(str[-14:-8:-1])
print(str[-8:-4:-1])
print(str[-8:-4:1])
print(str[::-1])
#print(str[-8: -4:0])
# Out:
# 16
# i
# i
# zent
# global
# global
# Kaizentrixglobal
# aizentrixglo
# azn
#
# gxirtne
#
#
# ixgl
# labolgxirtneziaK

# %% [markdown]
# ### Question 5
# Write a Python program for: **Python Program Implementation 5**

# %%
str1="arjuna"

# %% [markdown]
# ## Theory & Key Concepts Used in the Codes
#
# 1. **String Objects**: Creating and referencing string objects in memory.
# 2. **String Concatenation**: Joining strings together.
# 3. **Identity & Memory**: Understanding object references for strings in Python.
