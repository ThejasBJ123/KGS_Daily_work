# %% [markdown]
# ### 1 Given an integer array arr[], return the sum of all elements of arr.
#
# Examples:
#
# Input: arr[] = [1, 2, 3, 4]
# Output: 10
# Explanation: 1 + 2 + 3 + 4 = 10.
#
#  https://www.geeksforgeeks.org/problems/sum-all-array-elements/1

# %%
class Solution:
    def arraySum(self, arr):
        return sum(arr)

    
obj = Solution()
arr = [1, 2, 3, 4, 5]
print(obj.arraySum(arr))
# Out:
# 15

# %% [markdown]
# ### 2 Given an integer array arr[], return the sum of all elements of arr.
#
# Examples:
#
# Input: arr[] = [1, 2, 3, 4]
# Output: 10
# Explanation: 1 + 2 + 3 + 4 = 10.
#
# https://leetcode.com/problems/running-sum-of-1d-array/

# %%
class Solution:
    def runningSum(self, nums: list[int]) -> list[int]:
        total=0
        res=[]
        for i in nums:
            total=total+i
            res.append(total)
        return res

    
obj = Solution()
arr = [1, 2, 3, 4, 5]
print(obj.runningSum(arr))
# Out:
# [1, 3, 6, 10, 15]

# %% [markdown]
# ### 3 Mean or Average of an Array
# Solved
# Difficulty: BasicAccuracy: 70.83%Submissions: 115K+Points: 1
# Given an array arr[], return the floor value of the mean of its elements.
#
# Examples:
#
#
# Input: arr[] = [1, 3, 4, 2, 6, 5, 8, 7]
# Output: 4
# Explanation: Sum of the elements is 1 + 3 + 4 + 2 + 6 + 5 + 8 + 7 = 36, Mean = 36/8 = 4.5, floor(4.5) = 4.
#
# Input: arr[] = [4, 4, 4, 4, 4]
# Output: 4
# Explanation: Sum of the elements is 4 + 4 + 4 + 4 + 4 = 20, Mean = 20/5 = 4
# Constraints:
# 1 ≤ arr.size() ≤ 106
# 1 ≤ arr[i] ≤ 106
#
# https://www.geeksforgeeks.org/problems/mean0021/1

# %%
class Solution:
    def findMean(self, arr):
        # code here 
        lenarr = len(arr)   
        sumarr = sum(arr)
        result = sumarr//lenarr
        return result

arr = [1, 3, 4, 2, 6, 5, 8, 7]

lenarr = len(arr)
sumarr = sum(arr)

result = sumarr // lenarr

print(result)
# Out:
# 4
