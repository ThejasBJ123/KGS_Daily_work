# %% [markdown]
# # **Linear Search in an Array**
#
# ## **Question:**
# Write a Python program to create a user-defined integer array and check whether a given target element is available in the array using **Linear Search**. Return the index of the element and a boolean status indicating whether it was found.

# %%
def createIntArray():
    l1 = []
    while True:
        try:
            num = int(input("Enter the number: "))
            l1.append(num)
        except Exception as e:
            return l1

def linearSearch(arr, target):
    for i in range(0, len(arr)):
        if target == arr[i]:
            return i, True
    return -1, False

# Main program execution
print("Enter the elements in the array:")
arr = createIntArray()
print("The created array is:", arr)

target = int(input("Enter the element to search: "))
resInd, flag = linearSearch(arr, target)

if flag:
    print(target, "element is found at index", resInd)
else:
    print(target, "element is not found")
# Out:
# Enter the elements in the array:
# The created array is: [30, 63, 63, 5, 86, 78, 77]
# 55 element is not found

# %%
def createarray():
    l1=[]
    while True:
        try:
            n=int(input("Enter the number : "))
            l1.append(n)
        except Exception as e:
            return l1

def linearSearch(arr, target):
    for i in range(0, len(arr)):
        if target ==arr[i]:
            return i, True 
    return -1,False

print("create the array elements: ")
arr=createarray()
print("the array elements : ", arr)


target=int(input("Enter the target element:"))
resInd, flag=linearSearch(arr, target)
if flag:
    print(target,"the element found index:", resInd)
else:
    print(target,"the element not found index:", resInd)
# Out:
# create the array elements:
# the array elements :  [36, 69, 89, 56, 36, 78359, 36, 98, 69, 58, 36]
# 56 the element found index: 3
