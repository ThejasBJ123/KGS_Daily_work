# %% [markdown]
# # Alphabetic patterns:
# =====================
# python file                           PVM(Python)                                 Microprocessor
# (HILL)                          (Compiler + Interpreter)                            (Binary Lan)
#                                 Compiler ==> Converts HLL to Bytecode
#                                 interpreter ==>  Converts Bytecode to binary Lan
#
#
# - It is easy for PVM to convert the number I/p's to binary language. therefore, even the characters(i/e. anything that is enclosed within quotes of length 1) will be internally considered in a numeric format called as ASCII val's
#
#
#
# ### ASCII Val's :
#  It is interger representation of each and every single  character
#
#  - Totally there are 256 ASCII Val's , which is ranging form 0 to 255
#  -  the extended version of ASCII Val's , are called as UNICODE val's
#  -  ASCII  ==> American standard core of INformation interchange
#
# ' ' [space]   ==> 32
# '0' to '9'    ==> 48 to 57
# 'A' to 'Z'    ==> 65 to
# 'a' to 'z'    ==>
