# %% [markdown]
# ### **Features of list**
#
# 1. heterogenous
# 2. dynamic in nature
# 3. muttable
# 4. sorting / Reverse is easy
# 5. duplicate are allowed
#
# Syntax:   var_name=[val1, val2, val3,........valn]

# %%
L=[10,20.5, 45, "rama",True]

print(L)

print(len(L))
print(type(L))
# Out:
# [10, 20.5, 45, 'rama', True]
# 5
# <class 'list'>
