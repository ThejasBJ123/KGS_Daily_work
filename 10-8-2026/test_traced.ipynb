# %% [markdown]
# # Python Study Notebook: Test
# ### Questions, Unchanged User Code, Detailed Logic & Step-by-Step Code Tracing
#
# ---

# %% [markdown]
# ## Section 1: str= input("Enter the email id: ")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (str= input("Enter the email id: ")): Implement and trace the Python program for str= input("enter the email id: ").**
#
# ---
# ### 💻 My Code

# %%
str= input("Enter the email id: ")
print(str)
print(str[-4:])
print(str[-10:-4])
print(str[::-1])
# Out:
# ateha@gmail.com
# .com
# @gmail
# moc.liamg@aheta

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 2: a_num= input("enter the aadhaar number : ")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (a_num= input("enter the aadhaar number : ")): Implement and trace the Python program for a_num= input("enter the aadhaar number : ").**
#
# ---
# ### 💻 My Code

# %%
a_num= input("enter the aadhaar number : ")
print(a_num[:4])
print(a_num[-4:])
print(a_num[4:8])
print(a_num[:4],a_num[4:8], a_num[8:12], sep="-")
# Out:
# 1122
# 5566
# 3344
# 1122-3344-5566

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 3: com="Kaizentrix Global Solutions"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (com="Kaizentrix Global Solutions"): Implement and trace the Python program for com="kaizentrix global solutions".**
#
# ---
# ### 💻 My Code

# %%
com="Kaizentrix Global Solutions"

print(com[:10])
print(com[-9:])
print(com[::2])
print(com[::-1])
print(len(com))
# Out:
# Kaizentrix
# Solutions
# Kieti lblSltos
# snoituloS labolG xirtneziaK
# 27

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 4: p_num="Python@123"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (p_num="Python@123"): Implement and trace the Python program for p_num="python@123".**
#
# ---
# ### 💻 My Code

# %%
p_num="Python@123"
print(p_num[:6])
print(p_num[-3:])
print(p_num[7])
print(p_num[::-1])
print(len(p_num))
# Out:
# Python
# 123
# 1
# 321@nohtyP
# 10

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 5: M_Name="Kalki2898AD"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (M_Name="Kalki2898AD"): Implement and trace the Python program for m_name="kalki2898ad".**
#
# ---
# ### 💻 My Code

# %%
M_Name="Kalki2898AD"

print(M_Name[:5])
print(M_Name[-4:])
print(M_Name[::-1])
print(M_name[2:8])
# Out:
# Kalki
# 98AD

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 6: S_num="KA01AB1234"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (S_num="KA01AB1234"): Implement and trace the Python program for s_num="ka01ab1234".**
#
# ---
# ### 💻 My Code

# %%
S_num="KA01AB1234"

print(S_num[:2])
print(S_num[2:4])
print(S_num[5:7])
print(S_num[-4:])
# Out:
# KA
# 01
# B1
# 1234

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 7: account=input("entre there number : ")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (account=input("entre there number : ")): Implement and trace the Python program for account=input("entre there number : ").**
#
# ---
# ### 💻 My Code

# %%
account=input("entre there number : ")

print("*********"+account[-4:])


print("*" * len(account[:-4]) + account[-4:])
# Out:
# *********1354
# *********1354

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 8: stu=input("enter com: ")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (stu=input("enter com: ")): Implement and trace the Python program for stu=input("enter com: ").**
#
# ---
# ### 💻 My Code

# %%
stu=input("enter com: ")
print(stu[:4])
print(stu[4:8])
print(stu[-4:])
# Out:
# AIML
# 2026
# 0045

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 9: website="https://www.google.com"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (website="https://www.google.com"): Implement and trace the Python program for website="https://www.google.com".**
#
# ---
# ### 💻 My Code

# %%
website="https://www.google.com"
print(website[:6])
print(website)
print(website[8:])
# Out:
# https:
# https://www.google.com
# www.google.com

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 10: f_n=input("Enter the first name :")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (f_n=input("Enter the first name :")): Implement and trace the Python program for f_n=input("enter the first name :").**
#
# ---
# ### 💻 My Code

# %%
f_n=input("Enter the first name :")
sn_n=input("Enter the  last name : ")

print(f_n+"."+sn_n)
print(f_n[0],sn_n[-1])
# Out:
# thejas.kumar
# t r

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 11: lap="LAP20265000HP"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (lap="LAP20265000HP"): Implement and trace the Python program for lap="lap20265000hp".**
#
# ---
# ### 💻 My Code

# %%
lap="LAP20265000HP"
print(lap[:3])
print(lap[3:7])
print(lap[-6:-2])
print(lap[-2:])
# Out:
# LAP
# 2026
# 5000
# HP

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 12: otp=input("Ener the otp: ")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (otp=input("Ener the otp: ")): Implement and trace the Python program for otp=input("ener the otp: ").**
#
# ---
# ### 💻 My Code

# %%
otp=input("Ener the otp: ")
print(otp[0])
print(otp[-1])
print(otp[::-1])

print(otp[::2])
# Out:
# 6
# 5
# 56566
# 655

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 13: code="KGS-BLR-PYT-101"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (code="KGS-BLR-PYT-101"): Implement and trace the Python program for code="kgs-blr-pyt-101".**
#
# ---
# ### 💻 My Code

# %%
code="KGS-BLR-PYT-101"
print(code[:3])
print(code[4:7])
print(code[8:11])
print(code[-3:])
# Out:
# KGS
# BLR
# PYT
# 101

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 14: p="PythonProgramming"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (p="PythonProgramming"): Implement and trace the Python program for p="pythonprogramming".**
#
# ---
# ### 💻 My Code

# %%
p="PythonProgramming"
print(p[:6])
print(p[6:])
print(p[::2])
print(p[::3])
print(p[::-1])
print(p[:8])
print(p[-6:])
print(p[4:13])
print(p[10:])
print(len(p))
print(p[1:16])
# Out:
# Python
# Programming
# PtoPormig
# PhPgmn
# gnimmargorPnohtyP
# PythonPr
# amming
# onProgram
# ramming
# 17
# ythonProgramming

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 15: team="RCBvsCSK2026"
#
# ### ❓ Question / Problem Statement
# **Problem Statement (team="RCBvsCSK2026"): Implement and trace the Python program for team="rcbvscsk2026".**
#
# ---
# ### 💻 My Code

# %%
team="RCBvsCSK2026"
print(team[:3])
print(team[5:8])
print(team[-4])
print(team[::-1])
# Out:
# RCB
# CSK
# 2
# 6202KSCsvBCR

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---
