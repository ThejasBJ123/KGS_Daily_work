# %%
s={10,40,"apple",True}
print(s)
print(type(s))

s1={}
print(type(s1))


s2=set()
print(type(s2))
# print(s[2])
# print(s[1:])

# in sets the indexing and slicing concept ar not allowed.
# Out:
# {40, True, 10, 'apple'}
# <class 'set'>
# <class 'dict'>
# <class 'set'>
