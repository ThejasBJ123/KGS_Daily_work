# %%
s1={1,2,3,4}
s2={3,4,5,6}

print(s1.union(s2))
print(s2.intersection(s2))

print(s1.difference(s2))
print(s2.difference(s1))

print(s1.symmetric_difference(s2))
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4, 5, 6}
# {1, 2}
# {5, 6}
# {1, 2, 5, 6}

# %%
s1={1,2,3,4}
s2={3,4,5,6}
s3={7,8,9,10}


print(s1.isdisjoint(s2))
print(s2.isdisjoint(s3))
print(s1.isdisjoint(s3))
# Out:
# False
# True
# True

# %%
s1={1,2,3,4}
s2={1,2}

print(s1.issuperset(s2))
print(s1.issubset(s2))

print(s2.issuperset(s1))
print(s2.issubset(s1))
# Out:
# True
# False
# False
# True

# %% [markdown]
# # **frozenset**
#
# * immuttable
#
# - syntax:   var=frozenset([ele1,else2,..........,elen])
#
#             var.name=fronzenset()

# %%
f=frozenset([10,20,30,40,50])
print(f)
print(type(f))
# Out:
# frozenset({40, 10, 50, 20, 30})
# <class 'frozenset'>

# %%
s={1,2,3,4,{10,20,30},5,6}
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s={1,2,3,4,{10,20,30},5,6}
#       2 print(s)
#
# TypeError: unhashable type: 'set'

# %%
s={1,2,3,4(10,20,30),5,6}
print(s)
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\user\AppData\Local\Temp\ipykernel_19840\2965198764.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   s={1,2,3,4(10,20,30),5,6}
# C:\Users\user\AppData\Local\Temp\ipykernel_19840\2965198764.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   s={1,2,3,4(10,20,30),5,6}
# C:\Users\user\AppData\Local\Temp\ipykernel_19840\2965198764.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   s={1,2,3,4(10,20,30),5,6}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s={1,2,3,4(10,20,30),5,6}
#       2 print(s)
#
# TypeError: 'int' object is not callable

# %%
s={1,2,3,4,(10,20,30),5,6}
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, (10, 20, 30)}
