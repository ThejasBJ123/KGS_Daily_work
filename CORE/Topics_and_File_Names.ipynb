# %% [markdown]
# # 📚 Sandhya Mam - Completed Topics & File Names Reference
#
# ---
#
# ## 📌 Summary
# - **Total Topics Covered:** 8 Major Modules (27 Topic Notebooks & Projects)
# - **Total Workspace Files:** 50 Files

# %% [markdown]
# ## 📖 Completed Topics List
#
# | # | Topic / Module Name | Description / Coverage | Files Involved |
# |---|---|---|---|
# | 1 | **Python Basics & Notes** | Variables, Data Types, I/O, Arithmetic & Logical Operators | `DAY_1_Python_Basics_Notes.ipynb` |
# | 2 | **String Slicing & Formatting** | Indexing, Slicing `[start:stop:step]`, `f-strings`, String methods | `string_slicing_and_formatting.ipynb`, `Python_String_Programs.ipynb`, `slicing.ipynb` |
# | 3 | **Data Structures - Lists** | List operations, Appending, Popping, Slicing, List Comprehension | `list.ipynb`, `student_list.py` |
# | 4 | **Functions & Functional Programming** | Scope (LEGB), Map, Filter, Lambda functions, Closures, Decorators | `python_functions_and_scope.ipynb`, `map_and_lambda_functions.ipynb`, `filter_function_practice.ipynb`, `nested_functions_closures.ipynb`, `python_decorators.ipynb` |
# | 5 | **Numerical Algorithms & Logic** | Even/Odd, Leap Year, Factors, Primes, GCD, Armstrong numbers, Palindromes | `even_odd_and_leapyear.ipynb`, `factors_primes_gcd.ipynb`, `armstrong_palindrome_reverse.ipynb`, `oops_concepts_and_ascii.ipynb`, `utility_calculators.ipynb` |
# | 6 | **OOP Core Concepts** | Classes, Objects, Method Types (Instance, Class `@classmethod`, Static `@staticmethod`), Identity `id()`, Delegation | `DAY_2_OOP_Methods_and_Instance_Variables_Notes.ipynb`, `object_memory_identity.ipynb`, `oop_method_types.ipynb`, `Deligancy.ipynb`, `employee_id_generator.ipynb`, `intern_details_oop.ipynb` |
# | 7 | **Four Pillars of OOP** | Abstraction, Encapsulation, Inheritance, Polymorphism | `oop_abstraction.ipynb`, `oop_encapsulation.ipynb`, `oop_inheritance.ipynb`, `oop_polymorphism.ipynb` |
# | 8 | **Exception Handling** | `try`, `except`, `else`, `finally`, Custom Exception classes | `exception.ipynb` |
# | 9 | **Practical Mini-Projects** | ATM System, Bank Transaction Analyzer, BMI Calculator, GST Calculator, Flight Ticket Booking, Visitor Management | `Atm.py`, `Bank_tran_Analyzer.py`, `Bmi_cal.py`, `Employee_Id.py`, `Gst_cal.py`, `plane.py`, `visitor_management.py` |

# %% [markdown]
# ## 📁 Complete File Names & Paths List
#
# | File Name | Folder | Relative Path | Absolute Path |
# | --- | --- | --- | --- |
# | `exception.ipynb` | `Exception_Handling` | `Exception_Handling\exception.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Exception_Handling\exception.ipynb` |
# | `oop_abstraction.ipynb` | `Four_Pillars` | `Four_Pillars\oop_abstraction.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Four_Pillars\oop_abstraction.ipynb` |
# | `oop_encapsulation.ipynb` | `Four_Pillars` | `Four_Pillars\oop_encapsulation.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Four_Pillars\oop_encapsulation.ipynb` |
# | `oop_inheritance.ipynb` | `Four_Pillars` | `Four_Pillars\oop_inheritance.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Four_Pillars\oop_inheritance.ipynb` |
# | `oop_polymorphism.ipynb` | `Four_Pillars` | `Four_Pillars\oop_polymorphism.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Four_Pillars\oop_polymorphism.ipynb` |
# | `filter_function_practice.ipynb` | `Functions` | `Functions\filter_function_practice.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Functions\filter_function_practice.ipynb` |
# | `map_and_lambda_functions.ipynb` | `Functions` | `Functions\map_and_lambda_functions.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Functions\map_and_lambda_functions.ipynb` |
# | `nested_functions_closures.ipynb` | `Functions` | `Functions\nested_functions_closures.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Functions\nested_functions_closures.ipynb` |
# | `python_decorators.ipynb` | `Functions` | `Functions\python_decorators.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Functions\python_decorators.ipynb` |
# | `list.ipynb` | `List` | `List\list.ipynb` | `c:\KGS_CLASS\sandhya_Mam\List\list.ipynb` |
# | `armstrong_palindrome_reverse.ipynb` | `Numericals` | `Numericals\armstrong_palindrome_reverse.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Numericals\armstrong_palindrome_reverse.ipynb` |
# | `even_odd_and_leapyear.ipynb` | `Numericals` | `Numericals\even_odd_and_leapyear.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Numericals\even_odd_and_leapyear.ipynb` |
# | `factors_primes_gcd.ipynb` | `Numericals` | `Numericals\factors_primes_gcd.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Numericals\factors_primes_gcd.ipynb` |
# | `oops_concepts_and_ascii.ipynb` | `Numericals` | `Numericals\oops_concepts_and_ascii.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Numericals\oops_concepts_and_ascii.ipynb` |
# | `python_functions_and_scope.ipynb` | `Numericals` | `Numericals\python_functions_and_scope.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Numericals\python_functions_and_scope.ipynb` |
# | `Deligancy.ipynb` | `OOPs` | `OOPs\Deligancy.ipynb` | `c:\KGS_CLASS\sandhya_Mam\OOPs\Deligancy.ipynb` |
# | `employee_id_generator.ipynb` | `OOPs` | `OOPs\employee_id_generator.ipynb` | `c:\KGS_CLASS\sandhya_Mam\OOPs\employee_id_generator.ipynb` |
# | `intern_details_oop.ipynb` | `OOPs` | `OOPs\intern_details_oop.ipynb` | `c:\KGS_CLASS\sandhya_Mam\OOPs\intern_details_oop.ipynb` |
# | `object_memory_identity.ipynb` | `OOPs` | `OOPs\object_memory_identity.ipynb` | `c:\KGS_CLASS\sandhya_Mam\OOPs\object_memory_identity.ipynb` |
# | `oop_concepts_visitor_system.ipynb` | `OOPs` | `OOPs\oop_concepts_visitor_system.ipynb` | `c:\KGS_CLASS\sandhya_Mam\OOPs\oop_concepts_visitor_system.ipynb` |
# | `oop_method_types.ipynb` | `OOPs` | `OOPs\oop_method_types.ipynb` | `c:\KGS_CLASS\sandhya_Mam\OOPs\oop_method_types.ipynb` |
# | `PYTHON PRESENTATION TOPICS.odt` | `Tasks` | `Tasks\PYTHON PRESENTATION TOPICS.odt` | `c:\KGS_CLASS\sandhya_Mam\Tasks\PYTHON PRESENTATION TOPICS.odt` |
# | `DAY_1_Python_Basics_Notes.ipynb` | `Tasks\NOTES` | `Tasks\NOTES\DAY_1_Python_Basics_Notes.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Tasks\NOTES\DAY_1_Python_Basics_Notes.ipynb` |
# | `DAY_2_OOP_Methods_and_Instance_Variables_Notes.ipynb` | `Tasks\NOTES` | `Tasks\NOTES\DAY_2_OOP_Methods_and_Instance_Variables_Notes.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Tasks\NOTES\DAY_2_OOP_Methods_and_Instance_Variables_Notes.ipynb` |
# | `ppt3921.pptx  -  AutoRecovered.pptx` | `Tasks\core\Presentation` | `Tasks\core\Presentation\ppt3921.pptx  -  AutoRecovered.pptx` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\Presentation\ppt3921.pptx  -  AutoRecovered.pptx` |
# | `task.pptx` | `Tasks\core\Presentation` | `Tasks\core\Presentation\task.pptx` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\Presentation\task.pptx` |
# | `~$task.pptx` | `Tasks\core\Presentation` | `Tasks\core\Presentation\~$task.pptx` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\Presentation\~$task.pptx` |
# | `ex.py` | `Tasks\core\program1` | `Tasks\core\program1\ex.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\program1\ex.py` |
# | `new.py` | `Tasks\core\program1` | `Tasks\core\program1\new.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\program1\new.py` |
# | `new.py` | `Tasks\core\program2` | `Tasks\core\program2\new.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\program2\new.py` |
# | `pgm1.py` | `Tasks\core\program2` | `Tasks\core\program2\pgm1.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\program2\pgm1.py` |
# | `pgm2.py` | `Tasks\core\program2` | `Tasks\core\program2\pgm2.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\program2\pgm2.py` |
# | `new.py` | `Tasks\core\program3` | `Tasks\core\program3\new.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\program3\new.py` |
# | `Atm.py` | `Tasks\core\task` | `Tasks\core\task\Atm.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\Atm.py` |
# | `Bank_tran_Analyzer.py` | `Tasks\core\task` | `Tasks\core\task\Bank_tran_Analyzer.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\Bank_tran_Analyzer.py` |
# | `Bmi_cal.py` | `Tasks\core\task` | `Tasks\core\task\Bmi_cal.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\Bmi_cal.py` |
# | `Employee_Id.py` | `Tasks\core\task` | `Tasks\core\task\Employee_Id.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\Employee_Id.py` |
# | `Gst_cal.py` | `Tasks\core\task` | `Tasks\core\task\Gst_cal.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\Gst_cal.py` |
# | `plane.py` | `Tasks\core\task` | `Tasks\core\task\plane.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\plane.py` |
# | `string_slicing_and_formatting.ipynb` | `Tasks\core\task` | `Tasks\core\task\string_slicing_and_formatting.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\string_slicing_and_formatting.ipynb` |
# | `student_list.py` | `Tasks\core\task` | `Tasks\core\task\student_list.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\student_list.py` |
# | `utility_calculators.ipynb` | `Tasks\core\task` | `Tasks\core\task\utility_calculators.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\utility_calculators.ipynb` |
# | `visitor_management.py` | `Tasks\core\task` | `Tasks\core\task\visitor_management.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\visitor_management.py` |
# | `image copy.png` | `Tasks\core\task\question` | `Tasks\core\task\question\image copy.png` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\question\image copy.png` |
# | `image.png` | `Tasks\core\task\question` | `Tasks\core\task\question\image.png` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task\question\image.png` |
# | `Bank_tran_Analyzer.py` | `Tasks\core\task1` | `Tasks\core\task1\Bank_tran_Analyzer.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task1\Bank_tran_Analyzer.py` |
# | `Employee_Id.py` | `Tasks\core\task1` | `Tasks\core\task1\Employee_Id.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task1\Employee_Id.py` |
# | `Python_String_Programs.ipynb` | `Tasks\core\task1` | `Tasks\core\task1\Python_String_Programs.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task1\Python_String_Programs.ipynb` |
# | `slicing.ipynb` | `Tasks\core\task1` | `Tasks\core\task1\slicing.ipynb` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task1\slicing.ipynb` |
# | `visitor_management.py` | `Tasks\core\task1` | `Tasks\core\task1\visitor_management.py` | `c:\KGS_CLASS\sandhya_Mam\Tasks\core\task1\visitor_management.py` |
