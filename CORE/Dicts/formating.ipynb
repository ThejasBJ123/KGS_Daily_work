# %% [markdown]
# # **output formating**

# %%
name="pavithra"
course="Python web development"
company ="Kaizentrix Global Solutions"
print(f"My name is {name}, i have choosen a role {course} at {company}" )
# Out:
# My name is pavithra, i have choosen a role Python web developmentatKaizentrix Global Solutions

# %%
per=86.98922
print(f"percenage= {per: 2f}%")

# %% [markdown]
# # **Separators**

# %%
print("kaizen","global","Solutions",sep="_", end="*")
