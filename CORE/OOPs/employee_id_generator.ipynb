# %% [markdown]
# # File Name: employee_id_generator.ipynb
# ## Subject: Python Practice Assignment (core33)

# %% [markdown]
# -->Employee ID generator....
# • static Variable: company_name, employee_count
# • Instance Variables: employee_name, department
# • Local Variable: employee_id (created inside generate_employee_id())
# • Constructor: __init__()
# • Instance Method: generate_employee_id()
# • Objects: emp1, emp2, emp3

# %% [markdown]
# ### Question 1: Core33 Exercise 1
# Write a Python program for: **Core33 Exercise 1**

# %%
class Employee:
    company_name="Kaizentrix Global solution"
    employee_count=1000
    def __init__(self, employee_name, department):
        self.employee_name=employee_name
        self.department=department
    
    def employee_generated_id(self):
        Employee.employee_count+=1
        employee_id="EMP"+"KGS"+str(Employee.employee_count)
        print("\n =====================================")
        print("CompanyName: ", Employee.company_name)
        print("Name: ", self.employee_name)
        print("Empoyee_id", employee_id)
        print("Department: ", self.department)
        print("/n =================================")

ename=input("Enter the name :  ")
Dept=input("Enter the Department : ")

 
e1=Employee(ename,Dept)
e1.employee_generated_id()
# Out:
# ...
# CompanyName:  Kaizentrix Global solution
# Name:  thejasbj
# Empoyee_id EMPKGS1001
# Department:  java
# /n =================================

# %% [markdown]
# ### Question 2: Core33 Exercise 2
# Write a Python program for: **Core33 Exercise 2**

# %%
str="RaMa"

s1= str.upper()
print(s1)

s2=str.lower()
print(s2)

s3=str.swapcase()
print(s3)
# Out:
# RAMA
# rama
# rAmA

# %% [markdown]
# ### Question 3
# Write a Python program for: **strip**

# %%
# strip

str= "  Rama is Sleeping   "

s1=str.strip()
print(s1)

s2=str.rstrip()
print(s2)

s3=str.lstrip()
print(s3)
# Out:
# Rama is Sleeping
#   Rama is Sleeping
# Rama is Sleeping

# %% [markdown]
# ### Question 3: Core33 Exercise 3
# Write a Python program for: **Core33 Exercise 3**

# %%
S1="Kaizentrid  global solution "
print(s1.startswith( "solution"))
# Out:
# False

# %% [markdown]
# Without using inbuilt function
#
# str = R A M A
#
# i/p = Rama
# o/p = amaR
#
# i/p= "Hello"
# o/p= "Helo"
#
# i/p="Kaizentrix global solutions"
# o/p=" Solution global Kaizentrix
#
# i/p = " Rama is sleeping and rama is snooring"
# o/p=" Rama is sleeping and snooring

# %% [markdown]
# ### Question 4: Core33 Exercise 4
# Write a Python program for: **Core33 Exercise 4**

# %%
str = "R A M A"
print(str.replace(" ",""))
# Out:
# RAMA

# %% [markdown]
# ### Question 5: Core33 Exercise 5
# Write a Python program for: **Core33 Exercise 5**

# %%
str = "R A M A"

for i in str:
    if i != " ":
        print(i, end="")
# Out:
# RAMA

# %% [markdown]
# ### Question 7
# Write a Python program for: **i/p = Rama**

# %%
# i/p = Rama
# o/p = amaR

s = "Rama"

new=""
for i in s:
     new=i+new

print(new)
# Out:
# amaR

# %% [markdown]
# ### Question 8
# Write a Python program for: **i/p="Kaizentrix global solutions"**

# %%
# i/p="Kaizentrix global solutions"
# o/p=" Solution global Kaizentrix

s1="Kaizentrix global solutions"


s2= s1.split()

new=""
for i in s2:
     new=i+" "+new

print(new)
# Out:
# ['Kaizentrix', 'global', 'solutions']
# 3
# solutions global Kaizentrix

# %% [markdown]
# ### Question 9
# Write a Python program for: **i/p= "Hello"**

# %%
# i/p= "Hello" 
# o/p= "Helo"

s = "Hello"

new = ""

for i in s:
    if i not in new:
        new = new + i

print(new)
# Out:
# Helo

# %% [markdown]
# ### Question 10
# Write a Python program for: **i/p = " Rama is sleeping and rama is snooring"**

# %%
# i/p = " Rama is sleeping and rama is snooring"
# o/p=" Rama is sleeping and snooring 

s= " Rama is sleeping and Rama is snooring"

s2=s.split()
new = ""

for i in s2:
    if i not in new:
        new = new +" "+ i

print(new)
# Out:
#  Rama is sleeping and snooring

# %% [markdown]
# ### Question 11
# Write a Python program for: **i/p = " Rama is sleeping and rama is snooring"**

# %%
# i/p = " Rama is sleeping and rama is snooring"
# o/p=" Rama is sleeping and snooring 

s= " Rama is sleeping and Rama is snooring"

s2=s.split()
new = ""
for i in s2:
    if i not in new:
        new = new +" "+ i

print(new)
# Out:
#  Rama is sleeping and snooring

# %% [markdown]
# ## Theory & Key Concepts Used in the Codes
#
# 1. **Employee Class**: Object-oriented structure for employee details.
# 2. **String Stripping**: Removing whitespace using `strip()`, `lstrip()`, `rstrip()`.
# 3. **Custom String Logic**: Reimplementing string operations without built-in helper methods.
