# %% [markdown]
# # function call ==>
#   it instructs the PVM to allocate a memory for the current acive block of code to get loaded along wiht the local variable to execte a specific logic
#
# # return statement :
# *  it is basically a keyword
# * it  is the last executable line of code, once return is executed within a fuction then no other line of code wihtin the block will work
# * usages:
#     - it helps to return val/val's from called fuction back to the function call
#     - it instructs the PVM to take back the exection control forom called function back to the fuction call
#     - it also instructs the PVM to de-allocate the memory which was provided during function call
#
# * every created function must have a "Return " statement . therfore even if the code doesn't include a " return" , python compiler will include a "default return statment "
#   - It executes only when the "return " included by the programmer does't  execute
#   - It cannot return any value
#
#  # how to decided the parameters of a recursive fuction?
#  1. the values which are updates in the current cycle and need to be carryforwarded to the next cycle for further execution of the operation
#  2. The variable val's that may not be updated but neeed to be carry forwared to the next cycle either for logic execution for logic execrtion or for the base condition
#
# #  what is *base condition* ?
#
# * The codition that helps to control the recursive fuction call.
# * If the condition is invalid / included then if may lead to "Recursion Error"
#
# # Difference between Initial function call and Recursion Function call?
#
# # Initial function call
# * It would be made outside the scope of the recursive function
# * It should hold the initial val's of the parameters
# * without providing an initial call of a function, it will not execute
#
# # Recursive Function call
#
# * It is the inclued wihtin the scope of a fuction whose logic need to be repeated
# * it hold's the val's required by the parameter that is neeeded by the next cycle / base condition to perform the further operations
#
# # how to build a recursive function ?
# * include a function declaration
# * include a logic to be repeated within the scope of the fuction
# * to repeat the logic include "Recursive function Call", by passing the values required by the next cycle for the further operations
# * recognise the parameters
# * Analyse and include the base condition as of when to exit the recursive function call
# * give the inital function call, outside the function by passing the first val's for the parameters

# %% [markdown]
# ## Theory & Key Concepts Used in the Codes
#
# 1. **Function Call Mechanics**: Memory allocation on call stack during function invocation.
# 2. **Stack Frame**: Local variables, return address, and parameters pushed per call.
