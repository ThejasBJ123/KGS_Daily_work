# %% [markdown]
# # Python Study Notebook: Core
# ### Questions, Unchanged User Code, Detailed Logic & Step-by-Step Code Tracing
#
# ---

# %% [markdown]
# ## Section 1: str=" be good do good "
#
# ### ❓ Question / Problem Statement
# **Problem Statement (str=" be good do good "): Implement and trace the Python program for str=" be good do good ".**
#
# ---
# ### 💻 My Code

# %%
str=" be good do good "

print(str)
str1= "good "

print(str1 in str)

print(str.index("good"))
print(str.find("good"))
print(str.count("good"))

print(str.rindex("good"))
print(str.rfind("good"))


print(str.find("bad"))

# print(str.index("bad")) ---- error
# Out:
#  be good do good
# True
# 4
# 4
# 2
# 12
# 12
# -1

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Core Execution:** Performs sequential instruction execution and output printing.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 2: name=input("Enter the name : ")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (name=input("Enter the name : ")): Implement and trace the Python program for name=input("enter the name : ").**
#
# ---
# ### 💻 My Code

# %%
name=input("Enter the name : ")
print(" Hi {}!".format(name))
# Out:
#  Hi raju!

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 3: name=input("enter the name: ")
#
# ### ❓ Question / Problem Statement
# **Problem Statement (name=input("enter the name: ")): Implement and trace the Python program for name=input("enter the name: ").**
#
# ---
# ### 💻 My Code

# %%
name=input("enter the name: ")
age=int(input("enter the age : "))
place=input("enter the place: ")

print(" name = {} \n age = {} \n Place= {} ".format(name , age, place))
# Out:
#  name = raju
#  age = 34
#  Place= hassan

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **User Input Handling:** Prompts user input and casts values (`int()`, `float()`) to appropriate numeric types.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 4: class Demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class Demo:
    def swap(self , a, b):
        print("befor swapping")
        print(a)
        print(b)

        temp=a
        a=b
        b=temp

        print("after the swapping ")
        print(a)
        print(b)

d1=Demo()
n1=100
n2=200

d1.swap(n1,n2)
# Out:
# befor swapping
# 100
# 200
# after the swapping
# 200
# 100

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `swap` to encapsulate reusable task logic.
# 2. **For Loop Iteration:** Iterates through sequence/range bounds (`range(start, stop)`).
# 3. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 5: class Demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class Demo:
     def disp(self, x=11, y=22, z=33):
        print(x)
        print(y)
        print(z)

d1=Demo()
a=10
b=20
c=30
d1.disp()

print("\n")
d1.disp(a,b,c)

print("\n")
d1.disp(a,b,c)

print("\n")
d1.disp(a,b)

print("\n")
d1.disp(b,c)

print("\n")
d1.disp(y=b,z=c)

print("\n")
d1.disp(x=a,y=b,z=c)
# Out:
# 11
# 22
# 33
#
#
# 10
# 20
# 30
#
#
# 10
# 20
# 30
#
#
# 10
# 20
# 33
#
#
# 20
# 30
# 33
#
#
# 11
# 20
# 30
#
#
# 10
# 20
# 30

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `disp` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 6: class Demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class Demo:
    def add(self, a, b):
        c=a+b
        return c

    def sub(self, a, b):
        c=a-b
        return c

    def mul(self, a, b):
        c=a*b
        return c
    
d1=Demo()

x=10
y=20

r1=d1.add(x, y)
print(r1)

r2=d1.sub(x, y)
print(r2)

r3=d1.mul(x, y)
print(r3)
# Out:
# 30
# -10
# 200

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `add, sub, mul` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).
# 3. **Return Statement:** Passes calculated result back to caller function.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---

# %% [markdown]
# ## Section 7: class Demo:
#
# ### ❓ Question / Problem Statement
# **Problem Statement (class Demo:): Implement and trace the Python program for class demo:.**
#
# ---
# ### 💻 My Code

# %%
class Demo:
     def arith_op(self, a, b):
        r1=a+b
        r2=a-b
        r3=a*b

        return r1, r2, r3

d1=Demo()

x=10
y=20


res1, res2, res3= d1.arith_op(x,y)

print(res1)
print(res2)
print(res3)
# Out:
# 30
# -10
# 200

# %% [markdown]
# ### 🧠 Logic & Explanation
# 1. **Modular Function Design:** Defines custom function(s) `arith_op` to encapsulate reusable task logic.
# 2. **Object-Oriented Programming:** Defines class structure with attributes and methods (`__init__`, static, or instance methods).
# 3. **Return Statement:** Passes calculated result back to caller function.

# %% [markdown]
# ### 🔍 Step-by-Step Code Tracing (Dry Run)
#
# #### Sample Execution Walkthrough
#
# **Initially:**
# - PVM loads variables and function definitions into memory.
#
# **Execution:**
# - Evaluates statements sequentially, executing conditions and loops.
#
# **Output:**
# - Returns calculated result or displays formatted stdout output.
#
# ---
#
# #### 💡 The Main Idea / Intuition to Remember
# - Sequential execution guarantees state updates at every step.
#
# ---
