# %%
def dN(n):
    if n >= 1:
        print(n)
        dN(n - 1)

n = int(input("Enter the num: "))

dN(n)
# Out:
# 4
# 3
# 2
# 1

# %%
def dN(n):
    if n >= 1:
        dN(n - 1)
        print(n)
    return 

n = int(input("Enter the num: "))
dN(n)
# Out:
# 1
# 2
# 3
# 4
