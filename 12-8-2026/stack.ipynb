# %%
def dN(n):
    if n >= 1:
        print(n)
        dN(n - 1)

n = int(input("Enter the num: "))

dN(n)
# Out:
# 4
# 3
# 2
# 1

# %%
def dN(n):
    if n >= 1:
        dN(n - 1)
        print(n)
    return 

n = int(input("Enter the num: "))
dN(n)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# # wap to display the following
# a.  n=4
#
# 4 3 2 1 1 2 3 4
# - 3rd var is not allowed , no changes to be done on the base cond, only single recusive funcion is allowed to be used
#
# b. n=4
#
#      1 2 3 4 4 3 2 1
#
# - only the single recursive function is allowed to be used

# %%
# write a program to reverse a given integer using recursion function

# n=7142    op : 2417

def reverseNum(n,rev):
    if n<=0:
        return rev
    rem=n%10
    rev=(rev*10)+rem
    n=n//10
    return reverseNum(n,rev)

num=int(input("Enter a num : "))
res=reverseNum(num,0)
print("The reversal of " ,num ,"is", res)
# Out:
# The reversal of  2536 is 6352

# %%
# write a program to palindrome a given integer using recursion function

# n=7142    op : 2417

def isIntPalindrome(n, rev, temp):
    if n<=0:
        return rev == temp

    rem=n%10
    rev=(rev*10)+rem
    n=n//10
    return isIntPalindrome(n, rev, temp)

num=int(input("Enter a number : "))
flag= isIntPalindrome(num , 0, num)
if flag:
    print(num," is the palindrome ")
else:
    print(num," is not a palindrome")
# Out:
# 121  is the palindrome
